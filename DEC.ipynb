# %%
def repeat(x):
    def Dec(func):
        def inner():
            for i in range(x):
                func()
        return inner
    return Dec
@repeat(4)
def greet():
    print("Hello")
greet()
# Out:
# Hello
# Hello
# Hello
# Hello

# %%
def fun(x):
    def fun2(y):
        def fun3():
            y()
        return fun3
    return fun2
k=fun(20)
k=30

@fun(4)
def greet():
    print("Hi")
greet()
# Out:
# Hi

# %%
def Dec(func):
    def inner():
        print("Start")
        func()
        print("End")
    return inner
@Dec
def greet():
    print("Hello")
greet()
# Out:
# Start
# Hello
# End
